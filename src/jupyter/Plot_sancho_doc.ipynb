# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os, sys
import getpass
user = getpass.getuser()
#TODO: Esto hay que cambiarlo para cada proyecto
os.chdir("/Users/"+user+"/Documents/D/Niebla/")

sys.path.append('src/aux/')
import aux_functions

sys.path.append('src/plot/')
import plot

############# ############# ############# ############# ############# ############# 


print(" # Loading data")
df = pd.read_csv("./log_files/predictions/preds.csv")

y_true = df["y_true"]

#Get models used (remove y_true from columns)
models_used = df.columns[1:]
# Out:
#  # Loading data

# %%
models_used[2]
# Out:
# 'MLP_simp-temp_split'

# %%
# %matplotlib notebook

m = models_used[0]

ret = aux_functions.get_exp_n_model_name(m)
print("  * " + ret["exp"] + " - " + ret["model"] )

x=np.arange(y_true.shape[0])

sns.scatterplot(x=x, y=y_true, color="blue")
sns.lineplot(x=x, y=y_true, color="blue")

y_pred = df[m]

sns.scatterplot(x=x, y=y_pred, color="red", marker="+")
sns.lineplot(x=x, y=y_pred, color="red")
# Out:
#   * temp_split - LinearReg
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

m = models_used[2]

ret = aux_functions.get_exp_n_model_name(m)
print("  * " + ret["exp"] + " - " + ret["model"] )

x=np.arange(y_true.shape[0])

sns.scatterplot(x=x, y=y_true, color="blue")
sns.lineplot(x=x, y=y_true, color="blue")

y_pred = df[m]

sns.scatterplot(x=x, y=y_pred, color="red", marker="+")
sns.lineplot(x=x, y=y_pred, color="red")
# Out:
#   * temp_split - MLP_simp
# <img src="data:image/png;base64,..." width="640">

# %%
y_true[0:300]
# Out:
# 0        39.166667
# 1        38.166667
# 2        66.500000
# 3      1231.916667
# 4      1951.000000
#           ...
# 295    2000.000000
# 296    2000.000000
# 297    2000.000000
# 298    1701.916667
# 299     471.750000
# Name: y_true, Length: 300, dtype: float64

# %%
df[m][0:300]
# Out:
# 0       421.968413
# 1       403.629881
# 2       617.753510
# 3       814.898606
# 4       858.982062
#           ...
# 295    2000.000000
# 296    2000.000000
# 297    1893.769248
# 298     843.060657
# 299    1058.528756
# Name: MLP_simp-temp_split, Length: 300, dtype: float64
